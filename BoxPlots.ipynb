# %%
import matplotlib.pyplot as plt
import numpy as np

# fake up some data
spread = np.random.rand(50) * 100
center = np.ones(25) * 50
flier_high = np.random.rand(10) * 100 + 100
flier_low = np.random.rand(10) * -100
data = np.concatenate((spread, center, flier_high, flier_low), 0)

# basic plot
plt.boxplot(data)

# notched plot
plt.figure()
plt.boxplot(data, 1)

# change outlier point symbols
plt.figure()
plt.boxplot(data, 0, 'gD')

# don't show outlier points
plt.figure()
plt.boxplot(data, 0, '')

# horizontal boxes
plt.figure()
plt.boxplot(data, 0, 'rs', 0)

# change whisker length
plt.figure()
plt.boxplot(data, 0, 'rs', 0, 0.75)

# fake up some more data
spread = np.random.rand(50) * 100
center = np.ones(25) * 40
flier_high = np.random.rand(10) * 100 + 100
flier_low = np.random.rand(10) * -100
d2 = np.concatenate((spread, center, flier_high, flier_low), 0)
data.shape = (-1, 1)
d2.shape = (-1, 1)
# data = concatenate( (data, d2), 1 )
# Making a 2-D array only works if all the columns are the
# same length.  If they are not, then use a list instead.
# This is actually more efficient because boxplot converts
# a 2-D array into a list of vectors internally anyway.
data = [data, d2, d2[::2, 0]]
# multiple box plots on one figure
plt.figure()
plt.boxplot(data)

plt.show()

# %%
import scipy.io as sio
data = sio.loadmat('/home/niharika-shimona/Documents/Projects/Tumour_Localisation/MRFminusLIUliberal.mat')
import matplotlib

# %%
fig, ax = plt.subplots(figsize=(20, 8))
font = {'family' : 'normal',
         'weight' : 'bold',
         'size'   : 16}
matplotlib.rc('axes',linewidth=2)
matplotlib.rc('font', **font)

boxprops = dict(linewidth=2)
flierprops = dict(markersize=10,
                  linestyle='none')
meanlineprops = dict(linestyle='--', linewidth=2.5, color='purple')


data1 = [data['MRFminusLIU1'], data['MRFminusLIU2'], data['MRFminusLIU3'], data['MRFminusLIU4'],data['MRFminusLIU5'], data['MRFminusLIU6'], data['MRFminusLIU7'], data['MRFminusLIU8'],data['MRFminusLIU9'], data['MRFminusLIU10'], data['MRFminusLIU11'], data['MRFminusLIU12'],data['MRFminusLIU13'], data['MRFminusLIU14'], data['MRFminusLIU15'], data['MRFminusLIU16'], data['MRFminusLIU17']]
# basic plot
plt.boxplot(data1,0,'rs',0,meanline='True',showmeans='True',widths=0.5, boxprops=boxprops,
            flierprops=flierprops,meanprops=meanlineprops,
            whiskerprops=boxprops )
ax.plot([0, 0], [0,18], 'k--', lw=3)
fig.suptitle('Our method vs Liu', fontsize=18, weight='bold')
ax.set_xlabel('Difference in Network Cohesion',fontsize=16,weight='bold')
ax.set_ylabel('Network number',fontsize=16,weight='bold')

plt.show()
figname = 'fig_LIU.png'
fig.savefig(figname) 
plt.close(fig)

# %%
data_Y = sio.loadmat('/home/niharika-shimona/Documents/Projects/Tumour_Localisation/MRFminusYEOliberal.mat')

# %%
fig, ax = plt.subplots(figsize=(21,10))
font = {'family' : 'normal',
         'weight' : 'bold',
         'size'   : 16}
matplotlib.rc('axes',linewidth=2)
matplotlib.rc('font', **font)
data2 = [data_Y['MRFminusYEO1'], data_Y['MRFminusYEO2'], data_Y['MRFminusYEO3'], data_Y['MRFminusYEO4'],data_Y['MRFminusYEO5'], data_Y['MRFminusYEO6'], data_Y['MRFminusYEO7'], data_Y['MRFminusYEO8'],data_Y['MRFminusYEO9'], data_Y['MRFminusYEO10'], data_Y['MRFminusYEO11'], data_Y['MRFminusYEO12'],data_Y['MRFminusYEO13'], data_Y['MRFminusYEO14'], data_Y['MRFminusYEO15'], data_Y['MRFminusYEO16'], data_Y['MRFminusYEO17']]
# basic plot
plt.boxplot(data2,0,'rs',0,meanline='True',showmeans='True',widths=0.5
           ,boxprops=boxprops,
            flierprops=flierprops,meanprops=meanlineprops,
            whiskerprops=boxprops )
ax.plot([0, 0], [0,18], 'k--', lw=3)
fig.suptitle('Our method vs Original', fontsize=18,weight='bold')
ax.set_xlabel('Difference in Network Cohesion',fontsize=16,weight='bold')
ax.set_ylabel('Network number',fontsize=16,weight='bold')

plt.show()
figname = 'fig_YEO.png'
fig.savefig(figname)   # save the figure to fil
plt.close(fig)

# %%
data_T = sio.loadmat('/home/niharika-shimona/Documents/Projects/Tumour_Localisation/taskBasedResults.mat')
data_T
# Out:
# {'MRFminusLIUfinger': array([[ 0.10075373,  0.03026326,  0.19384112,  0.02666091,  0.01230657,
#           0.07689282,  0.06110367,  0.19513775,  0.04814782, -0.00908343,
#          -0.00908343,  0.1826595 ,  0.09776644,  0.03703656,  0.02519114,
#           0.08083504,  0.14076053,  0.03654159,  0.02270532,  0.02766803,
#           0.06656158,  0.03047826, -0.12102666,  0.11051091,  0.03680508,
#           0.01889221, -0.02465925,  0.14676715,  0.14672324,  0.22840324,
#          -0.03107515,  0.0012935 ,  0.03112828,  0.14118031, -0.00757185,
#           0.00860723,  0.09563764,  0.08597323,  0.052303  ,  0.4430139 ,
#           0.05339932, -0.03872186]]),
#  'MRFminusLIUfoot': array([[ 0.07970972,  0.19167724,  0.04942921,  0.06858144,  0.03786517,
#           0.004506  ,  0.09170432,  0.09887973,  0.00977292,  0.09053439,
#           0.00767449,  0.07207024,  0.03324237,  0.07229878,  0.24988722,
#          -0.03035438, -0.01426876,  0.03857668,  0.12787186,  0.10746962]]),
# ...

# %%
data_fi = [data_T['MRFminusYEOfinger'],data_T['MRFminusLIUfinger']]
data_to = [data_T['MRFminusYEOtongue'],data_T['MRFminusLIUtongue']]
data_fo = [data_T['MRFminusYEOfoot'],data_T['MRFminusLIUfoot']]

# %%
import pylab
font = {'family' : 'normal',
         'weight' : 'bold',
         'size'   : 15}
matplotlib.rc('font', **font)
matplotlib.rc('axes',linewidth=2)
flierprops = dict(markersize=6,
                  linestyle='none')
whiskerprops =dict(linewidth=2)

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(14, 6))

# rectangular box plot
bplot1 = axes[0].boxplot(data_fi,
                         vert=True,   # vertical box aligmnent
                         patch_artist=True,zorder=-1   # fill with color
                         ,boxprops=boxprops,whiskerprops=whiskerprops,
                         flierprops=flierprops,meanprops=meanlineprops)

# notch shape box plot
bplot2 = axes[1].boxplot(data_to,
                         vert=True,   # vertical box aligmnent
                         patch_artist=True,zorder=-1   # fill with color
                         ,boxprops=boxprops,whiskerprops=whiskerprops,
                         flierprops=flierprops,meanprops=meanlineprops,
                         )

                         
bplot3 = axes[2].boxplot(data_fo,
                         vert=True,   # vertical box aligmnent
                         patch_artist=True,zorder=-1  # fill with color
                        ,boxprops=boxprops,whiskerprops=whiskerprops,
                         flierprops=flierprops,meanprops=meanlineprops)  

# fill with colors
colors = ['pink', 'lightblue']
for bplot in (bplot1, bplot2,bplot3):
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)
        

# add x-tick labels
plt.setp(axes, xticks=[y+1 for y in range(len(data_to))],
         xticklabels=['Ours vs Orig.', 'Ours vs Liu'])

for i in xrange(2):
    
    for tick in axes[i].xaxis.get_major_ticks():
        tick.label1.set_fontsize(15)
        tick.label1.set_fontweight('bold')
    for tick in axes[i].yaxis.get_major_ticks():
        tick.label1.set_fontsize(15)
        tick.label1.set_fontweight('bold')

fig.tight_layout() 

axes[0].plot([0, 1001], [0,0], 'k--', lw=3,zorder=1)
axes[0].set_title('Finger',fontsize =15,weight='bold')
axes[0].set_ylim([-0.16,0.28])

axes[1].plot([0, 1001], [0,0], 'k--', lw=3,zorder=1)
axes[1].set_title('Tongue',fontsize =15,weight='bold')
axes[1].set_ylim([-0.16,0.28])

axes[2].plot([0, 1001], [0,0], 'k--', lw=3,zorder=1)
axes[2].set_title('Foot',fontsize =15,weight='bold')
axes[2].set_ylim([-0.16,0.28])


plt.show()

figname = 'fig_task_based.png'
fig.savefig(figname)   # save the figure to fil
plt.close(fig)
